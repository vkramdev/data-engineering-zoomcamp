# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.2'

# %%
## Start a postgresql DB with volume attached at $(pwd)/ny_taxi_postgres_data on local machine
'''docker run -it \
-e POSTGRES_USER="root" \
-e POSTGRES_PASSWORD="root" \
-e POSTGRES_DB="ny_taxi" \
-v $(pwd)/ny_taxi_postgres_data:/var/lib/postgresql/data \
-p 5432:5432 \
postgres:13'''
# Out:
# 'docker run -it -e POSTGRES_USER="root" -e POSTGRES_PASSWORD="root" -e POSTGRES_DB="ny_taxi" -v $(pwd)/ny_taxi_postgres_data:/var/lib/postgresql/data -p 5432:5432 postgres:13'

# %%
## need to install fastparquet seperately .

# %%
data= pd.read_parquet("yellow_tripdata_2021-01.parquet", engine='fastparquet')

# %%
data.head(10)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
# 5         1  2021-01-01 00:16:29   2021-01-01 00:24:30              1.0
# 6         1  2021-01-01 00:00:28   2021-01-01 00:17:28              1.0
# 7         1  2021-01-01 00:12:29   2021-01-01 00:30:34              1.0
# 8         1  2021-01-01 00:39:16   2021-01-01 01:00:13              1.0
# 9         1  2021-01-01 00:26:12   2021-01-01 00:39:46              2.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10         1.0                  N           142            43
# ...

# %%
data.head(n=0)
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, RatecodeID, store_and_fwd_flag, PULocationID, DOLocationID, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge, airport_fee]
# Index: []

# %%
data.shape
# Out:
# (1369769, 19)

# %%
print(pd.io.sql.get_schema(data, name='ny_taxi_data'))
# Out:
# CREATE TABLE "ny_taxi_data" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TIMESTAMP,
#   "tpep_dropoff_datetime" TIMESTAMP,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "RatecodeID" REAL,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL,
#   "airport_fee" REAL
# )

# %%
## install psycopg2 seperately. pip install psycopg2-binary [The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. 
##For details see: </docs/install.html#binary-install-from-pypi>.]

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
## The below schema created by pandas is consistent with postgresql . just compare with the above schema

# %%
print(pd.io.sql.get_schema(data, name='ny_taxi_data', con=engine))
# Out:
# CREATE TABLE ny_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	airport_fee FLOAT(53)
# )

# %%
##df = pd.read_parquet("yellow_tripdata_2021-01.parquet", engine='fastparquet', iterator=True, chunksize=100000)

# %%
## TODO1 "Find way to ingest the parquet file data in batches in the postgresql directly
## without converting to pandas"
## TODO2 "Check if the below method is reading all the data from parquet file"
## TODO3 "Check how is the table created in the DB as the first insert is of batch 1L and not the table schema"
from time import time
import pyarrow.parquet as pa

data_p = pa.ParquetFile("yellow_tripdata_2021-01.parquet")

n=0

for i in data_p.iter_batches(batch_size=100000):
    t1=time()
    print("records")
    df = i.to_pandas()
    df.to_sql(name='yellow_taxi_data', con=engine, if_exists="append")
    t2=time()
    
    print(f"time to insert the batch = {t2-t1}")
# Out:
# records
# time to insert the batch = 5.698894500732422
# records
# time to insert the batch = 5.706920385360718
# records
# time to insert the batch = 5.630383729934692
# records
# time to insert the batch = 5.62433123588562
# records
# time to insert the batch = 5.742559194564819
# records
# time to insert the batch = 5.59623908996582
# records
# time to insert the batch = 5.650047302246094
# records
# time to insert the batch = 5.645548582077026
# records
# time to insert the batch = 5.676371812820435
# records
# time to insert the batch = 5.6071693897247314
# records
# time to insert the batch = 5.607115268707275
# records
# time to insert the batch = 5.74030065536499
# records
# time to insert the batch = 5.4824090003967285
# records
# time to insert the batch = 3.555009603500366

# %%
## Read data from postgresql DB with Pandas and sqlalchemy
## v=1.2.2
## from sqlalchemy import create_engine
## engine = create_engine('postgresql://username:password@url:port/DB_Schema_name')

# %%
query="""
SELECT * 
FROM pg_catalog.pg_tables
WHERE schemaname !='pg_catalog' AND
schemaname !='information_schema';
"""

# %%
pd.read_sql(query,con=engine)
# Out:
#   schemaname         tablename tableowner tablespace  hasindexes  hasrules  \
# 0     public  yellow_taxi_data       root       None        True     False
#
#    hastriggers  rowsecurity
# 0        False        False

# %%
query_read="""
SELECT * 
FROM yellow_taxi_data LIMIT 10
"""

# %%
pd.read_sql(query_read, con=engine)
# Out:
#    index  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0      0         1  2021-01-01 00:30:10   2021-01-01 00:36:12
# 1      1         1  2021-01-01 00:51:20   2021-01-01 00:52:19
# 2      2         1  2021-01-01 00:43:30   2021-01-01 01:11:06
# 3      3         1  2021-01-01 00:15:48   2021-01-01 00:31:01
# 4      4         2  2021-01-01 00:31:49   2021-01-01 00:48:21
# 5      5         1  2021-01-01 00:16:29   2021-01-01 00:24:30
# 6      6         1  2021-01-01 00:00:28   2021-01-01 00:17:28
# 7      7         1  2021-01-01 00:12:29   2021-01-01 00:30:34
# 8      8         1  2021-01-01 00:39:16   2021-01-01 01:00:13
# 9      9         1  2021-01-01 00:26:12   2021-01-01 00:39:46
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0              1.0           2.10         1.0                  N
# 1              1.0           0.20         1.0                  N
# 2              1.0          14.70         1.0                  N
# ...

# %%
## v=1.2.3
